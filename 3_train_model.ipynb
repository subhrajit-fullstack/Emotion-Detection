# %%
# ============================================
# Import Required Libraries
# ============================================

import tensorflow as tf

from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

import matplotlib.pyplot as plt

# ============================================
# Load Preprocessed Dataset
# ============================================

import numpy as np

X_train = np.load("X_train.npy")
X_test = np.load("X_test.npy")

y_train = np.load("y_train.npy")
y_test = np.load("y_test.npy")

print("Training Images :", X_train.shape)
print("Testing Images :", X_test.shape)

print("Training Labels :", y_train.shape)
print("Testing Labels :", y_test.shape)

# ============================================
# Build CNN Model
# ============================================

model = Sequential()

# First Convolution Layer
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))

# Second Convolution Layer
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# Third Convolution Layer
model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# Flatten Layer
model.add(Flatten())

# Fully Connected Layer
model.add(Dense(128, activation='relu'))

# Dropout Layer
model.add(Dropout(0.5))

# Output Layer
model.add(Dense(5, activation='softmax'))


# ============================================
# Model Summary
# ============================================

model.summary()

# ============================================
# Compile Model
# ============================================

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)


# ============================================
# Train Model
# ============================================

history = model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=20,
    batch_size=32
)


# ============================================
# Plot Training & Validation Accuracy
# ============================================

plt.figure(figsize=(8,5))

plt.plot(history.history["accuracy"], label="Training Accuracy", linewidth=2)
plt.plot(history.history["val_accuracy"], label="Validation Accuracy", linewidth=2)

plt.title("Training vs Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)

plt.show()


# ============================================
# Plot Training & Validation Loss
# ============================================

plt.figure(figsize=(8,5))

plt.plot(history.history["loss"], label="Training Loss", linewidth=2)
plt.plot(history.history["val_loss"], label="Validation Loss", linewidth=2)

plt.title("Training vs Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)

plt.show()

# ============================================
# Evaluate Model
# ============================================

test_loss, test_accuracy = model.evaluate(X_test, y_test)

print("\n========== Model Performance ==========")
print(f"Test Loss     : {test_loss:.4f}")
print(f"Test Accuracy : {test_accuracy*100:.2f}%")


# ============================================
# Save Trained Model
# ============================================

model.save("emotion_model.keras")

print("Model Saved Successfully.")


# ============================================
# Save Emotion Labels
# ============================================

import json

emotion_labels = {
    0: "angry",
    1: "happy",
    2: "neutral",
    3: "sad",
    4: "surprised"
}

with open("emotion_labels.json", "w") as file:
    json.dump(emotion_labels, file)

print("Emotion Labels Saved Successfully.")


# ============================================
# Training Completed
# ============================================

print("="*50)
print(" Emotion Detection Model Trained Successfully ")
print("="*50)

print("Files Created:")
print("1. emotion_model.keras")
print("2. emotion_labels.json")

print("\nProject Ready For Prediction.")
# Out:
# Training Images : (12865, 48, 48, 1)
# Testing Images : (3217, 48, 48, 1)
# Training Labels : (12865, 5)
# Testing Labels : (3217, 5)
# /Users/nexusop03/anaconda3/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 46, 46, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 23, 23, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 21, 21, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 10, 10, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 355,589 (1.36 MB)
#  Trainable params: 355,589 (1.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.3131 - loss: 1.5200 - val_accuracy: 0.4510 - val_loss: 1.3415
# Epoch 2/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.4570 - loss: 1.3009 - val_accuracy: 0.5359 - val_loss: 1.1751
# Epoch 3/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.5258 - loss: 1.1775 - val_accuracy: 0.5406 - val_loss: 1.1436
# Epoch 4/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.5674 - loss: 1.0957 - val_accuracy: 0.5887 - val_loss: 1.0318
# Epoch 5/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.5932 - loss: 1.0276 - val_accuracy: 0.6114 - val_loss: 1.0006
# Epoch 6/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.6159 - loss: 0.9780 - val_accuracy: 0.6254 - val_loss: 0.9800
# Epoch 7/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.6409 - loss: 0.9203 - val_accuracy: 0.6239 - val_loss: 0.9730
# Epoch 8/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.6595 - loss: 0.8724 - val_accuracy: 0.6301 - val_loss: 0.9600
# Epoch 9/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.6799 - loss: 0.8251 - val_accuracy: 0.6254 - val_loss: 0.9747
# Epoch 10/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.6971 - loss: 0.7843 - val_accuracy: 0.6301 - val_loss: 0.9763
# Epoch 11/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.7108 - loss: 0.7344 - val_accuracy: 0.6298 - val_loss: 0.9875
# Epoch 12/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.7304 - loss: 0.6893 - val_accuracy: 0.6260 - val_loss: 1.0256
# Epoch 13/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.7489 - loss: 0.6472 - val_accuracy: 0.6332 - val_loss: 1.0471
# Epoch 14/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.7586 - loss: 0.6262 - val_accuracy: 0.6307 - val_loss: 1.0517
# Epoch 15/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.7758 - loss: 0.5788 - val_accuracy: 0.6313 - val_loss: 1.1324
# Epoch 16/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.7879 - loss: 0.5458 - val_accuracy: 0.6332 - val_loss: 1.1496
# Epoch 17/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.8026 - loss: 0.5057 - val_accuracy: 0.6366 - val_loss: 1.2097
# Epoch 18/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.8094 - loss: 0.4894 - val_accuracy: 0.6170 - val_loss: 1.2907
# Epoch 19/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.8233 - loss: 0.4506 - val_accuracy: 0.6276 - val_loss: 1.3441
# Epoch 20/20
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.8340 - loss: 0.4200 - val_accuracy: 0.6142 - val_loss: 1.3880
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6142 - loss: 1.3880
#
# ========== Model Performance ==========
# Test Loss     : 1.3880
# Test Accuracy : 61.42%
# Model Saved Successfully.
# Emotion Labels Saved Successfully.
# ==================================================
#  Emotion Detection Model Trained Successfully
# ==================================================
# Files Created:
# 1. emotion_model.keras
# 2. emotion_labels.json
#
# Project Ready For Prediction.
